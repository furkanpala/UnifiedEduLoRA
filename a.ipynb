# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from datetime import datetime

print("Kernel keep-alive started. Stop the cell to end.")
i = 0
while True:
    print(f"[{datetime.now().strftime('%H:%M:%S')}] busy {i}", flush=True)
    i += 1
    time.sleep(60)
# Out:
# Kernel keep-alive started. Stop the cell to end.
# [09:05:21] busy 0
# [09:06:21] busy 1
# [09:07:21] busy 2
# [09:08:21] busy 3
# [09:09:21] busy 4
# [09:10:21] busy 5
# [09:11:21] busy 6
# [09:12:21] busy 7
# [09:13:21] busy 8
# [09:14:21] busy 9
# [09:15:21] busy 10
# [09:16:21] busy 11
# [09:17:21] busy 12
# [09:18:21] busy 13
# [09:19:21] busy 14
# [09:20:21] busy 15
# [09:21:21] busy 16
# [09:22:21] busy 17
# [09:23:21] busy 18
# [09:24:21] busy 19
# [09:25:21] busy 20
# [09:26:21] busy 21
# [09:27:21] busy 22
# [09:28:21] busy 23
# [09:29:21] busy 24
# [09:30:21] busy 25
# [09:31:21] busy 26
# [09:32:21] busy 27
# [09:33:21] busy 28
# [09:34:21] busy 29
# [09:35:21] busy 30
# [09:36:21] busy 31
# [09:37:21] busy 32
# [09:38:21] busy 33
# [09:39:21] busy 34
# [09:40:21] busy 35
# [09:41:21] busy 36
# [09:42:21] busy 37
# [09:43:21] busy 38
# [09:44:21] busy 39
# [09:45:21] busy 40
# [09:46:21] busy 41
# [09:47:21] busy 42
# ...

# %%
python experiments/10_eval_checkpoint.py \
    --checkpoint-dir /content/drive/MyDrive/unifiedfl_fed_experiment/federated/fed_final \
    --splits-dir     /content/drive/MyDrive/unifiedfl_fed_experiment/splits \
    --output-dir     /content/drive/MyDrive/unifiedfl_fed_experiment/federated/fed_final_results \
    --label          "final_round"
    
    
    
python experiments/09_compare_results.py \
    --indiv-dir /content/drive/MyDrive/unifiedfl_fed_experiment/individual \
    --fed-dir   /content/drive/MyDrive/unifiedfl_fed_experiment/federated/fed_final_results \
    --save      /content/drive/MyDrive/unifiedfl_fed_experiment/comparison_finalround.json
